# %%
# 本地运行cpu环境运行请添加以下被注释的命令，gpu环境请参考官网gpu版paddle安装
#!pip install paddlepaddle==2.4.0
# !pip install lightgbm==3.3.5
# !pip install scikit-learn==1.0.2
# !pip install joblib==1.2.0
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: lightgbm==3.3.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (3.3.5)
# Requirement already satisfied: scipy in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from lightgbm==3.3.5) (1.6.3)
# Requirement already satisfied: numpy in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from lightgbm==3.3.5) (1.19.5)
# Requirement already satisfied: wheel in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from lightgbm==3.3.5) (0.36.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from lightgbm==3.3.5) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.5) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.5) (1.2.0)

# %%
#导入需要的包
# %matplotlib inline
import os
import warnings
import pandas as pd
import numpy as np
import shutil
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor, early_stopping
from paddle.io import Dataset
from sklearn.metrics import mean_squared_error,mean_absolute_error
import paddle
import paddle.nn as nn
import paddle.optimizer as optim
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1 数据集分析
# ## 1.1 数据预处理（此处数据预处理采用原作者基线方案，链接：https://aistudio.baidu.com/aistudio/projectdetail/5866171?contributionType=1&sUid=90149&shared=1&ts=1680491732413）

# %%
# # 解压缩数据集
# # !unzip -O GBK 区域赛训练集.zip
# !unzip -O GBK 处理后数据.zip

# %% [markdown]
# 本次比赛重点侧重于模型算法的落地应用，因此，数据集高度贴近风电企业实际情况，选手开发数据集处理方法，需要同时适配不同格式的风机数据。预选赛提供10个风场的数据，区域赛会提供新的10个风场数据用于新的训练和预测，数据格式的情况可能会更为复杂，本文总结了风场数据可能存在的各种情况：
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/6ff0922de0f548de9d1c0483d24421dc84439a6eabbb44f78acfcb8a4adac0d0)

# %% [markdown]
# 针对以上问题，可以确定如下的数据集处理思路：
# 1. 将风机数据统一为csv格式
# 2. 将同一个风机的多条数据进行拼接，按时间戳进行排序，合成一个文件

# %%
def data_preprocess(data_dir):
    files = os.listdir(data_dir)
    # 第一步，完成数据格式统一
    for f in files:
        # 获取文件路径
        data_file = os.path.join(data_dir, f)
        # 获取文件名后缀
        data_type = os.path.splitext(data_file)[-1]
        # 获取文件名前缀
        data_name = os.path.splitext(data_file)[0]
        # 如果是excel文件，进行转换
        if data_type == '.xlsx':
            # 需要特别注意的是，在读取excel文件时要指定空值的显示方式，否则会在保存时以字符“.”代替，影响后续的数据分析
            data_xls = pd.read_excel(data_file, index_col=0, na_values='')
            data_xls.to_csv(data_name + '.csv', encoding='utf-8')
            # 顺便删除原文件
            os.remove(data_file)
    # 第二步，完成多文件的合并，文件目录要重新更新一次
    files = os.listdir(data_dir)
    for f in files:
        # 获取文件路径
        data_file = os.path.join(data_dir, f)
        # 获取文件名前缀
        data_basename = os.path.basename(data_file)
        # 检查风机数据是否有多个数据文件
        if len(data_basename.split('-')) > 1:
            merge_list = []
            # 找出该风机的所有数据文件
            matches = [f for f in files if (f.find(data_basename.split('-')[0] + '-') > -1)]
            for i in matches:
                # 读取风机这部分数据
                data_df = pd.read_csv(os.path.join(data_dir, i), index_col=False, keep_default_na=False)
                merge_list.append(data_df)
            if len(merge_list) > 0:
                all_data = pd.concat(merge_list, axis=0, ignore_index=True).fillna(".")
                all_data.to_csv(os.path.join(data_dir, data_basename.split('-')[0] + '.csv'), index=False)
            for i in matches:
                # 删除这部分数据文件
                os.remove(os.path.join(data_dir, i))
            # 更新文件目录
            files = os.listdir(data_dir)

# %%
data_preprocess('区域赛训练集')

# %% [markdown]
# 至此，我们完成了数据集的批量预处理，将各种风机不同格式、不同数量文件的数据集进行了统一。这样，在后续的时序数据预测中，我们只需要对csv格式的时序数据进行处理即可。

# %%
os.listdir('区域赛训练集')
# Out:
# ['19.csv',
#  '17.csv',
#  '14.csv',
#  '12.csv',
#  '18.csv',
#  '13.csv',
#  '11.csv',
#  '15.csv',
#  '16.csv',
#  '20.csv']

# %% [markdown]
# # 2 模型应用
# ## 2.1 数据集准备
# 在数据集分析时，我们可以不对数据缺失值进行处理以保持数据原貌。但是在模型训练时，则必须指定缺失值的处理方式，否则训练会报错。

# %%
# 创建model目录，保存文件
folder_path = "./model"
if os.path.exists(folder_path):
    shutil.rmtree(folder_path)
os.mkdir(folder_path)

# %%
class RegressionDataset(Dataset):
    def __init__(self, x, y):
        super().__init__()
        self.features = x
        self.targets = y

    def __getitem__(self, index):
        x = paddle.to_tensor(self.features[index], dtype='float32')
        y = paddle.to_tensor(self.targets[index], dtype='float32')
        return x, y

    def __len__(self):
        return len(self.features)

# %%
# # 这里采用一号风机做样例
# tur_id = 1
# n = 2 - len(str(tur_id))
# filename = '0' * n + str(tur_id) + '.csv'
# data = pd.read_csv("功率预测竞赛赛题与数据集/" + filename)

# # ===========异常值处理===========
# # 当实际风速为0时，功率置为0
# data.loc[data['ROUND(A.WS,1)']==0, 'YD15'] = 0

# # TODO 风速过大但功率为0的异常：先设计函数拟合出：实际功率=f(风速)，
# # 然后代入异常功率的风速获取理想功率，替换原异常功率

# # TODO 对于在特定风速下的离群功率（同时刻用IQR检测出来），做功率修正（如均值修正）
# for sp in data['WINDSPEED'].unique():
#     dfs = data.loc[data['WINDSPEED']==sp,'YD15']
#     dfs=dfs.sort_values()
#     Q1=dfs.quantile(0.25)
#     Q3=dfs.quantile(0.75)
#     IQR=Q3-Q1;
#     down=Q1-1.5*IQR
#     up=Q3+1.5*IQR
#     data.loc[(data['WINDSPEED']==sp)&(data['YD15']<down),'YD15']=down
#     data.loc[(data['WINDSPEED']==sp)&(data['YD15']>up),'YD15']=up

# data.dropna(subset=["YD15"], inplace=True) #删除YD15为空的行
# data_mean = data.mean(axis=0)
# data = data.fillna(value=data_mean)  #用平均值填充其它列的空值
# new_data = data.copy()
# # 回归数据集自身特点，还是可以看中回归任务
# train = new_data[["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
# print(train)

# %% [markdown]
# ## 3.1 方案一：单模型预测
# ### 3.1.1 GCN单模型训练

# %%
# 定义GCN模型
class GCN(nn.Layer):

    def __init__(self, input_size, hidden_size, output_size):
        super(GCN, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, output_size)
        self.relu = nn.ReLU()

    def forward(self, x, adj):
        x = paddle.matmul(adj, x) #计算乘积
        x = self.linear1(x)
        x = self.relu(x)
        x = paddle.matmul(adj, x)
        x = self.linear2(x)
        return x


# 定义数据集
class GraphDataset(paddle.io.Dataset):
    def __init__(self, x, y, use_gpu):
        super().__init__()
        self.x = x
        self.y = y
        self.gpukry = use_gpu
        if use_gpu:
            self.x = paddle.to_tensor(x,place='gpu')
            self.y = paddle.to_tensor(y,place='gpu')

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.x)

# %%
def matplot_loss(train_loss):
    plt.plot(train_loss, label='train_loss')
    plt.legend(loc='best')
    plt.ylabel('loss', fontsize=12)
    plt.xlabel('epoch', fontsize=12)
    plt.title("loss")
    plt.show()

# %%
# 注意这里的参数请自行设定，笔者为了加速验证过程调小了batch_size,epochs数量，建议batch_size为2的n次方，epochs建议高于20
def trainModel(dataset, input_size=7, hidden_size=64, output_size=1, learning_rate=0.01, batch_size=2, epochs=30,
               use_gpu=False):
    """

    :param input_size: 输入特征大小默认是7
    :param hidden_size: 隐藏层大小默认是7
    :param output_size: 输出层大小默认是1
    :param learning_rate: 学习率默认是0.01
    :param batch_size: batch数据大小默认是2
    :param epochs: 训练批次默认是10
    :use_gpu: 是否使用gpu默认是False
    :return: 返回训练好的model
    """

    # 构建GCN模型
    model = GCN(input_size, hidden_size, output_size)
    if use_gpu:
        paddle.set_device('gpu')
        model=model.to('gpu')
    else:
        paddle.set_device('cpu')

    x_train, x_test, y_train, y_test = dataset
    # 将特征值和目标值转换为float32类型
    x_train = x_train.astype('float32')
    y_train = y_train.astype('float32')
    x_test = x_test.astype('float32')
    y_test = y_test.astype('float32')
    # 定义数据加载器
    train_dataset = GraphDataset(x_train, y_train, use_gpu)
    train_loader = paddle.io.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    # 定义优化器和损失函数
    optimizer = optim.Adam(parameters=model.parameters(), learning_rate=learning_rate)
    criterion = nn.MSELoss()

    # 模型训练
    for epoch in range(epochs):
        loss = None
        for x, y in train_loader:
            adj = paddle.ones((x.shape[0], x.shape[0]))  # 假设所有节点之间都有连接
            output = model(x, adj)
            loss = criterion(output, y)
            loss.backward()
            optimizer.step()
            optimizer.clear_grad()
        print(f'model epoch{epoch} loss is {loss}')

    # 模型评估
    test_dataset = GraphDataset(x_test, y_test, False)
    test_loader = paddle.io.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    model.eval()
    total_loss = 0
    with paddle.no_grad():
        for x, y in test_loader:
            adj = paddle.ones((x.shape[0], x.shape[0]))  # 假设所有节点之间都有连接
            output = model(x, adj)
            # print(output)
            # print(output.shape)
            loss = criterion(output, y)
            total_loss += loss.numpy().item() * x.shape[0]

    mean_loss = total_loss / len(test_dataset)
    print("Mean Loss on Test Set: {:.4f}".format(mean_loss))
    # matplot_loss(mean_loss)
    return model

# %%
# # 模型评估
# model = trainModel(dataset=(x_train, x_test, y_train, y_test),epochs=2,use_gpu=False)
# with paddle.no_grad():
#     adj = paddle.ones((x_test.shape[0], x_test.shape[0]))  # 假设所有节点之间都有连接
#     output = model(paddle.to_tensor(x_test, dtype="float32"), adj)
#     print(output)
#     print(output.shape)

# %%
# # 模型保存
# paddle.save(model.state_dict(), "model/" + str(tur_id) + ".pdparams")

# %% [markdown]
# ### 3.1.2 GCN单模型批量训练

# %%
def mutiTrain_GCN(start, end):
    for i in range(start, end+1):
        n = 2 - len(str(i))
        filename = '0' * n + str(i) + '.csv'
        data = pd.read_csv("区域赛训练集/" + filename)

        # # ===========异常值处理===========
        # # 当实际风速为0时，功率置为0
        # data.loc[data['ROUND(A.WS,1)']==0, 'YD15'] = 0

        # # TODO 风速过大但功率为0的异常：先设计函数拟合出：实际功率=f(风速)，
        # # 然后代入异常功率的风速获取理想功率，替换原异常功率

        # # TODO 对于在特定风速下的离群功率（同时刻用IQR检测出来），做功率修正（如均值修正）
        # for sp in data['WINDSPEED'].unique():
        #     dfs = data.loc[data['WINDSPEED']==sp,'YD15']
        #     dfs=dfs.sort_values()
        #     Q1=dfs.quantile(0.25)
        #     Q3=dfs.quantile(0.75)
        #     IQR=Q3-Q1;
        #     down=Q1-1.5*IQR
        #     up=Q3+1.5*IQR
        #     data.loc[(data['WINDSPEED']==sp)&(data['YD15']<down),'YD15']=down
        #     data.loc[(data['WINDSPEED']==sp)&(data['YD15']>up),'YD15']=up
        
        data.dropna(subset=["YD15"], inplace=True)
        data_mean = data.mean(axis=0)
        data = data.fillna(value=data_mean)
        new_data = data.copy()
        train = new_data[
            ["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
        print(train.shape)
        target = new_data[['YD15']].values
        x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
        
        model = trainModel(dataset=(x_train, x_test, y_train, y_test), batch_size=256, epochs=40,use_gpu=True)
        paddle.save(model.state_dict(), "model/" + str(i) + ".pdparams")

# %%
# %%time
mutiTrain_GCN(11,20)
# Out:
# (23136, 7)
# W0614 11:14:58.376343   220 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.2, Runtime API Version: 11.2
# W0614 11:14:58.381611   220 gpu_resources.cc:91] device: 0, cuDNN Version: 8.2.
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2648242432.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10338301952.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2079151104.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2351676160.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4640833536.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8925767680.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24264019968.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3700633600.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [13852844032.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2736822784.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2916882432.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3485758976.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4633962496.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5323113472.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [19810478080.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8179301376.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3478993920.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3867073792.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2852413952.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2633213952.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3513909248.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [13647486976.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6779082752.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3645015552.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6388525056.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [22884134912.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [105337339904.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2932302592.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3701957632.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1915515392.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [18270220288.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [42950541312.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [39976718336.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1333213134848.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2242740224000.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24277123072.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24312741888.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7214278656.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6276977664.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6234525696.])
# Mean Loss on Test Set: 3183080642801.6182
# (23232, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [71182098432.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [29144647680.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3890931456.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1413742720.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2239775232.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [34498490368.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3550270464.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2371015168.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [13809753088.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10095583232.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1429658752.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9786841088.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [18014885888.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [55678808064.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4431661568.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7024088064.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [15379047424.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1674739712.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8510090752.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [22168752128.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [11623879680.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [18715742208.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1939070464.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [113698684928.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [27623059456.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7840672256.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [32367378432.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3219184896.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [28160358400.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [27194396672.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [43626590208.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8161847296.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [41305317376.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [83998105600.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [45565632512.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2450824192.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [484760387584.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [66120880128.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1587189383168.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [199213318144.])
# Mean Loss on Test Set: 3055247046702.2651
# (37824, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [48866144256.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [27806271488.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [532554252288.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [274641354752.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [45145001984.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [97984864256.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [832082752.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [39841792000.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [85772124160.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [262493765632.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [66442264576.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [43769409536.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [26287220736.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [418258681856.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8564564992.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [44914028544.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [361053028352.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [158817779712.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7042385920.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [20563552256.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24645394432.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [50401681408.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1953255680.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [85063188480.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [50141802496.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [403749666816.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [860275933184.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8587331584.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7704821760.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [109647798272.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1717036416.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1099759616.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [118258679808.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [302265008128.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [666285441024.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1660442880.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [123926323658752.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2557212622848.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4938299904.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [98582487040.])
# Mean Loss on Test Set: 61876035771.8551
# (37728, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [58469306368.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [34197567488.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2367933120512.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [493851148288.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [191471812608.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [54599979008.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [406863380480.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [151277699072.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [167675248640.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [49277112320.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1533014400.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1608582400.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2738321152.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [14304358400.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5471539712.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [680374272.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [53029847040.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [41090969600.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [29661972480.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [12171878400.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [448030769152.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [684238569472.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [131496132608.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4734634496.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [148348829696.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [21705728000.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [26223751168.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1054325604352.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [16968898560.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2650184876032.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8145416192.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [55897276416.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9434279936.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2347440896.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [15894790144.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [22424473600.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2741741824.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [194707210240.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3140288768.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [298799202304.])
# Mean Loss on Test Set: 6681026922419.4648
# (43680, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4462962176.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5155668992.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1498907264.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5257234432.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1856298496.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3825746176.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2886518272.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4011121152.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2843735040.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [13078637568.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7473680384.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3316493568.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1613069440.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2937827840.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3323935232.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4476418048.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5743809536.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2296436224.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1553633920.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [58807435264.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [31243782144.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4324821041152.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2087596160.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1731638591488.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [42184650752.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [21036216320.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1694300928.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [86270083072.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [20463333933056.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3418618880.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [17221482496.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4900779520.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8490484224.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10677593088.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2125502080.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [11600946176.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3258327552.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [930203172864.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8240567808.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [162091565056.])
# Mean Loss on Test Set: 9982449737449.4941
# (13759, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [162629173248.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [12971557888.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [668914624.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [938590464.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1657218176.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9783145472.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [702976768.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10085334016.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [27449942016.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [767397632.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [916883328.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4968851456.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [609173568.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2798973440.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [989836800.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8056433664.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2293626880.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [20856602624.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7607922176.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [912902272.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [759854848.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1269596544.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [898884416.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1817585664.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [833846208.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3029262336.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3476668160.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [665592320.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2118071936.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [646841856.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3886351872.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3676054784.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1760425344.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8344825856.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6491767808.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3972425984.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [844360192.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [741636736.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9813286912.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [12634148864.])
# Mean Loss on Test Set: 175525229794.2325
# (37824, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [134600859648.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1243986304.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1259693184.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6744184832.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1014136000.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1054500096.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1134630144.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1039416128.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [741668608.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5581824000.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5241259520.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1833846656.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7128548352.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [988590464.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [950815680.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [895146624.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [884342592.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8251203584.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7041590272.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3382091520.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [27819503616.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [37505236992.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9212195840.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4735556096.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [20166612992.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9449876480.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6763659264.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7100480512.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10016312320.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10480501760.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8731655168.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1096994176.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [74980499456.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [184517656576.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5084293120.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4694707535872.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [599847337984.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2304792320.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3899460352.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [640100073472.])
# Mean Loss on Test Set: 21410412964.6439
# (12863, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [581158699008.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1669224448.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [632161152.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1586920960.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [366413984.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [811527808.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1076605184.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [214329824.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [592606080.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [282200544.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [621474176.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [694003968.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [285845120.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1065112320.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8277857280.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1961667584.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [169840544.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [230057888.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2489529088.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [182599936.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [250227904.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1156630528.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [152179136.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [831715840.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [566474688.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [178234048.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1325514112.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [543058176.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [167575456.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [193732016.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [427890304.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1005535680.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [338723936.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4378575360.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [165040416.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1606975744.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [583027072.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [763909760.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [1946117504.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [257383568.])
# Mean Loss on Test Set: 14850765655.3970
# (12181, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [40312915361792.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [10343740866560.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8836313088.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2719851520.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4442246144.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2893375488.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2697489664.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3288390912.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2055137792.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [5394341376.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [15317786624.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2937286912.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9798593536.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2522871296.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2871545344.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2600230912.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [37730881536.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9185223680.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2532033280.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [14629342208.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3107995392.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3113453824.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [11289870336.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2551245312.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2720985088.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [14601305088.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2680176384.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3810836992.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9047080960.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4413990400.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2878928896.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [7554000384.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4067067392.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3861559552.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3515737088.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2460243968.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4026347776.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2258590720.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [32511815680.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8073311232.])
# Mean Loss on Test Set: 10283287658.4742
# (20390, 7)
# model epoch0 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3235018440704.])
# model epoch1 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3425219072.])
# model epoch2 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [43081900032.])
# model epoch3 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [113785348096.])
# model epoch4 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [9988446208.])
# model epoch5 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [239481536512.])
# model epoch6 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [251138736.])
# model epoch7 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [164209754112.])
# model epoch8 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [37620903936.])
# model epoch9 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24247668736.])
# model epoch10 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3738903552.])
# model epoch11 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24462336000.])
# model epoch12 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [644839936.])
# model epoch13 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [34891980800.])
# model epoch14 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [38657171456.])
# model epoch15 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [3044575744.])
# model epoch16 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [36496416768.])
# model epoch17 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [21282775040.])
# model epoch18 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [42799960064.])
# model epoch19 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [44518211584.])
# model epoch20 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [62465437696.])
# model epoch21 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [24050917376.])
# model epoch22 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [97512816640.])
# model epoch23 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [4139825152.])
# model epoch24 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [105830703104.])
# model epoch25 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [88210350080.])
# model epoch26 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [39718891520.])
# model epoch27 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [129225965568.])
# model epoch28 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [6133071872.])
# model epoch29 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [273466080.])
# model epoch30 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [20203677696.])
# model epoch31 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [57250680832.])
# model epoch32 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [15458761728.])
# model epoch33 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [52511350784.])
# model epoch34 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [165585846272.])
# model epoch35 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [23685332992.])
# model epoch36 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [334940832.])
# model epoch37 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [80565026816.])
# model epoch38 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [8777425920.])
# model epoch39 loss is Tensor(shape=[1], dtype=float32, place=Place(gpu:0), stop_gradient=False,
#        [2754179328.])
# Mean Loss on Test Set: 1781832569983.0583
# CPU times: user 6min 27s, sys: 9.99 s, total: 6min 37s
# Wall time: 6min 10s

# %% [markdown]
# ## 3.2 方案一：单模型预测
# ### 3.2.1 gbm单模型训练

# %%
# # 这里采用一号风机做样例
# tur_id = 1
# n = 2 - len(str(tur_id))
# filename = '0' * n + str(tur_id) + '.csv'
# data = pd.read_csv("区域赛训练集/" + filename)
# data.dropna(subset=["YD15"], inplace=True)
# data_mean = data.mean(axis=0)
# data = data.fillna(value=data_mean)
# new_data = data.copy()
# # 回归数据集自身特点，还是可以看中回归任务
# train = new_data[["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
# print(train.shape)
# target = new_data[['YD15']].values
# # %%
# x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)

# %%
# #定义模型 这里参数自行设定，获取不同调优结果，也可采用CV来调参
# gbm = LGBMRegressor(
#     boosting_type = 'gbdt', 
#     objective = 'regression', 
# 	learning_rate = 0.01, 
#     n_estimators = 20000,
#     n_jobs = -1,
#     num_leaves = 50, 
#     max_depth = 14,
# 	min_child_samples = 21,   			#min_child_samples
# 	min_child_weight = 0.001,	        #min_child_weight
# 	subsample = 1.0,					#bagging_fraction
# 	colsample_bytree = 0.8,		    	#feature_fraction
# 	reg_alpha = 0.01,					#reg_alpha
# 	reg_lambda = 0,						#reg_lambd
#     )

# %%
# # 模型训练
# # 指定训练集，验证集，采用l1正则化验证评估，10rounds训练损失没有下降停止，可以增至200~2000左右，这个本地训练更快一些
# gbm.fit(x_train, y_train, eval_set=[(x_test, y_test)], eval_metric="l1",
#         callbacks=[early_stopping(stopping_rounds=500)])

# %%
# # 模型预测
# y_pre_gbm = gbm.predict(x_test)
# # 模型评估


# print(f"gbm {tur_id} mean_absolute_error:{mean_squared_error(y_test, y_pre_gbm)}")
# print(f"gbm {tur_id} score:{gbm.score(x_test, y_test)}")

# %% [markdown]
# # 调参

# %%
tur_id = 11
n = 2 - len(str(tur_id))
filename = '0' * n + str(tur_id) + '.csv'
data = pd.read_csv("区域赛训练集/" + filename)
data.dropna(subset=["YD15"], inplace=True)
data_median= data.median(axis=0)
data_mean = data.mean(axis=0)
data = data.fillna(value=data_median)
new_data = data.copy()
# 回归数据集自身特点，还是可以看中回归任务
train = new_data[["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
print(train.shape)
target = new_data[['YD15']].values
# %%
x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
# Out:
# (23136, 7)

# %%
import lightgbm as lgb

params = {    
  'boosting_type': 'gbdt', 
  'objective': 'regression', 
  'learning_rate': 0.1, 
  'num_leaves': 50, 
	'max_depth': 13,    
	'subsample': 0.8, 
  'colsample_bytree': 0.8, 
  }
data_train = lgb.Dataset(x_train, y_train, silent=True)
#lightgbm.cv官方文档https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.cv.html
cv_results = lgb.cv(
  params, 
  data_train, 
  num_boost_round=5000, 
  nfold=5, 
  stratified=False, 
  shuffle=True, 
  metrics='rmse',
  early_stopping_rounds=50, 
  verbose_eval=50, 
  show_stdv=True, 
  seed=0)
print('best n_estimators:', len(cv_results['rmse-mean']))
print('best cv score:', cv_results['rmse-mean'][-1])
n_estimators = len(cv_results['rmse-mean'])
best_cv_score = cv_results['rmse-mean'][-1]
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.804982 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 16656, number of used features: 7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 1.002338 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 16656, number of used features: 7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.804279 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 16656, number of used features: 7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 1.004058 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 16656, number of used features: 7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 1.001442 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1192
# [LightGBM] [Info] Number of data points in the train set: 16656, number of used features: 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_182/3467620845.py in <module>
#      23   verbose_eval=50,
#      24   show_stdv=True,
# ---> 25   seed=0)
#      26 print('best n_estimators:', len(cv_results['rmse-mean']))
#      27 print('best cv score:', cv_results['rmse-mean'][-1])
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/lightgbm/engine.py in cv(params, train_set, num_boost_round, folds, nfold, stratified, shuffle, metrics, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, fpreproc, verbose_eval, show_stdv, seed, callbacks, eval_train_metric, return_cvbooster)
#     638                                     end_iteration=num_boost_round,
#     639                                     evaluation_result_list=None))
# --> 640         cvfolds.update(fobj=fobj)
#     641         res = _agg_cv_result(cvfolds.eval_valid(feval), eval_train_metric)
#     642         for _, key, mean, _, std in res:
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/lightgbm/engine.py in handler_function(*args, **kwargs)
#     351             ret = []
#     352             for booster in self.boosters:
# --> 353                 ret.append(getattr(booster, name)(*args, **kwargs))
#     354             return ret
#     355         return handler_function
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    3021             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3022                 self.handle,
# -> 3023                 ctypes.byref(is_finished)))
#    3024             self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    3025             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
# 粗调
### 我们可以创建lgb的sklearn模型，使用上面选择的(学习率，评估器数目)
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=50,
                              learning_rate=0.1, n_estimators=1716, max_depth=10,
                              metric='rmse', bagging_fraction = 0.8,
                              feature_fraction = 0.8)
params_test1={    
			'max_depth': range(16,19,1),     #16,17,18
			'num_leaves':range(56, 60, 1)   #56,57,58,59
			}   #一共12个组合
gsearch1 = GridSearchCV(estimator=model_lgb, 
						param_grid=params_test1, 
						scoring='neg_mean_squared_error', 
						cv=5, 	   #交叉验证参数，默认None，使用三折交叉验证。指定fold数量，默认为3，也可以是yield训练/测试数据的生成器。
						verbose=1, #日志冗长度，int：冗长度，0：不输出训练过程，1：偶尔输出，>1：对每个子模型都输出。
						n_jobs=-1  #并行数，-1即跟cpu核数一致
						)
gsearch1.fit(x_train, y_train)
means = gsearch1.cv_results_['mean_test_score']
params = gsearch1.cv_results_['params']
print(means)
print(params)
print(gsearch1.best_params_)
print(gsearch1.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [-1.93994642e+08 -1.96183097e+08 -1.93447617e+08 -1.94779838e+08
#  -1.93040949e+08 -1.94808509e+08 -1.94633941e+08 -1.95644824e+08
#  -1.95895187e+08 -1.95127796e+08 -1.93356587e+08 -1.95915240e+08]
# [{'max_depth': 16, 'num_leaves': 56}, {'max_depth': 16, 'num_leaves': 57}, {'max_depth': 16, 'num_leaves': 58}, {'max_depth': 16, 'num_leaves': 59}, {'max_depth': 17, 'num_leaves': 56}, {'max_depth': 17, 'num_leaves': 57}, {'max_depth': 17, 'num_leaves': 58}, {'max_depth': 17, 'num_leaves': 59}, {'max_depth': 18, 'num_leaves': 56}, {'max_depth': 18, 'num_leaves': 57}, {'max_depth': 18, 'num_leaves': 58}, {'max_depth': 18, 'num_leaves': 59}]
# {'max_depth': 17, 'num_leaves': 56}
# -193040949.18770856

# %%
# import lightgbm as lgb
# from sklearn.model_selection import GridSearchCV
# params_test2={
#     # 'max_depth': range(13,20,3),
#     'max_depth': [15,16,17],
#     'num_leaves':[50,55,60,65,70,75,80,85]
# }
# gsearch2 = GridSearchCV(estimator=model_lgb, 
# 						param_grid=params_test2, 
# 						scoring='neg_mean_squared_error', 
# 						cv=5, verbose=1, n_jobs=4)
# gsearch2.fit(x_train, y_train)
# means = gsearch2.cv_results_['mean_test_score']
# params = gsearch2.cv_results_['params']
# print(means)
# print(params)
# print(gsearch2.best_params_)
# print(gsearch2.best_score_)

# %%
# import lightgbm as lgb
# from sklearn.model_selection import GridSearchCV
params_test3={
    'min_child_samples': [15,16,17,18,19],
    'min_child_weight':[0.001, 0.002]
}
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=56,
                              learning_rate=0.1, n_estimators=1716, max_depth=17, 
                              metric='rmse', bagging_fraction = 0.8, feature_fraction = 0.8)
gsearch3 = GridSearchCV(estimator=model_lgb, 
                        param_grid=params_test3, 
                        scoring='neg_mean_squared_error', 
                        cv=5, verbose=1, n_jobs=-1)
gsearch3.fit(x_train, y_train)
means = gsearch3.cv_results_['mean_test_score']
params = gsearch3.cv_results_['params']
print(means)
print(params)
print(gsearch3.best_params_)
print(gsearch3.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [-1.91829149e+08 -1.91829149e+08 -1.93643367e+08 -1.93643367e+08
#  -1.93192683e+08 -1.93192683e+08 -1.92753440e+08 -1.92753440e+08
#  -1.93940560e+08 -1.93940560e+08]
# [{'min_child_samples': 15, 'min_child_weight': 0.001}, {'min_child_samples': 15, 'min_child_weight': 0.002}, {'min_child_samples': 16, 'min_child_weight': 0.001}, {'min_child_samples': 16, 'min_child_weight': 0.002}, {'min_child_samples': 17, 'min_child_weight': 0.001}, {'min_child_samples': 17, 'min_child_weight': 0.002}, {'min_child_samples': 18, 'min_child_weight': 0.001}, {'min_child_samples': 18, 'min_child_weight': 0.002}, {'min_child_samples': 19, 'min_child_weight': 0.001}, {'min_child_samples': 19, 'min_child_weight': 0.002}]
# {'min_child_samples': 15, 'min_child_weight': 0.001}
# -191829148.7725261

# %%
params_test4={
		    'feature_fraction': [0.5, 0.6, 0.7, 0.8, 0.9],
		    'bagging_fraction': [0.6, 0.7, 0.8, 0.9, 1.0]
			}
model_lgb = lgb.LGBMRegressor(objective='regression',
								num_leaves=56,
                             	learning_rate=0.1, 
								n_estimators=1716, 
								max_depth=17, 
                             	metric='rmse',
								bagging_freq = 5,  
								min_child_samples=15)
gsearch4 = GridSearchCV(estimator=model_lgb, 
						param_grid=params_test4, 
						scoring='neg_mean_squared_error', 
						cv=5, verbose=1, n_jobs=-1)
gsearch4.fit(x_train, y_train)
means = gsearch4.cv_results_['mean_test_score']
params = gsearch4.cv_results_['params']
print(means)
print(params)
print(gsearch4.best_params_)
print(gsearch4.best_score_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5[LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# ...
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [-2.03129702e+08 -2.03129702e+08 -2.01059551e+08 -1.98886344e+08
#  -1.98886344e+08 -1.99898931e+08 -1.99898931e+08 -1.97180812e+08
#  -1.96106335e+08 -1.96106335e+08 -2.01426581e+08 -2.01426581e+08
#  -1.94547450e+08 -1.92146162e+08 -1.92146162e+08 -2.00249296e+08
#  -2.00249296e+08 -1.91526763e+08 -1.92417579e+08 -1.92417579e+08
#  -1.99152899e+08 -1.99152899e+08 -1.95010679e+08 -1.91829149e+08
#  -1.91829149e+08]
# [{'bagging_fraction': 0.6, 'feature_fraction': 0.5}, {'bagging_fraction': 0.6, 'feature_fraction': 0.6}, {'bagging_fraction': 0.6, 'feature_fraction': 0.7}, {'bagging_fraction': 0.6, 'feature_fraction': 0.8}, {'bagging_fraction': 0.6, 'feature_fraction': 0.9}, {'bagging_fraction': 0.7, 'feature_fraction': 0.5}, {'bagging_fraction': 0.7, 'feature_fraction': 0.6}, {'bagging_fraction': 0.7, 'feature_fraction': 0.7}, {'bagging_fraction': 0.7, 'feature_fraction': 0.8}, {'bagging_fraction': 0.7, 'feature_fraction': 0.9}, {'bagging_fraction': 0.8, 'feature_fraction': 0.5}, {'bagging_fraction': 0.8, 'feature_fraction': 0.6}, {'bagging_fraction': 0.8, 'feature_fraction': 0.7}, {'bagging_fraction': 0.8, 'feature_fraction': 0.8}, {'bagging_fraction': 0.8, 'feature_fraction': 0.9}, {'bagging_fraction': 0.9, 'feature_fraction': 0.5}, {'bagging_fraction': 0.9, 'feature_fraction': 0.6}, {'bagging_fraction': 0.9, 'feature_fraction': 0.7}, {'bagging_fraction': 0.9, 'feature_fraction': 0.8}, {'bagging_f
# {'bagging_fraction': 0.9, 'feature_fraction': 0.7}
# -191526762.80602986

# %%
params_test5={
    'feature_fraction': [0.62, 0.65, 0.68, 0.7, 0.72, 0.75, 0.78 ]
			}
model_lgb = lgb.LGBMRegressor(objective='regression',	
								num_leaves=56,
                             	learning_rate=0.1, 
								n_estimators=1716, 
								max_depth=17, 
                              	metric='rmse',  
								min_child_samples=15)
gsearch5 = GridSearchCV(estimator=model_lgb, 
						param_grid=params_test5, 
						scoring='neg_mean_squared_error', 
						cv=5, verbose=1, n_jobs=-1)
gsearch5.fit(x_train, y_train)
# print(gsearch5.grid_scores_, gsearch5.best_params_, gsearch5.best_score_)
means = gsearch5.cv_results_['mean_test_score']
params = gsearch5.cv_results_['params']
print(means)
print(params)
print(gsearch5.best_params_)
print(gsearch5.best_score_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [-1.99152899e+08 -1.95010679e+08 -1.95010679e+08 -1.95010679e+08
#  -1.95010679e+08 -1.95010679e+08 -1.95010679e+08]
# [{'feature_fraction': 0.62}, {'feature_fraction': 0.65}, {'feature_fraction': 0.68}, {'feature_fraction': 0.7}, {'feature_fraction': 0.72}, {'feature_fraction': 0.75}, {'feature_fraction': 0.78}]
# {'feature_fraction': 0.65}
# -195010678.9639312

# %%
params_test6={
    'reg_alpha': [0, 0.001, 0.01, 0.03, 0.08, 0.3, 0.5],
    'reg_lambda': [0, 0.001, 0.01, 0.03, 0.08, 0.3, 0.5]
}
model_lgb = lgb.LGBMRegressor(objective='regression',
								num_leaves=56,
								learning_rate=0.1, 
								n_estimators=1716, 
								max_depth=17, 
								metric='rmse',  
								min_child_samples=15, 
								feature_fraction=0.65)
gsearch6 = GridSearchCV(estimator=model_lgb, 
						param_grid=params_test6, 
						scoring='neg_mean_squared_error', 
						cv=5, verbose=1, n_jobs=-1)
gsearch6.fit(x_train, y_train)

means = gsearch6.cv_results_['mean_test_score']
params = gsearch6.cv_results_['params']
print(means)
print(params)
print(gsearch6.best_params_)
print(gsearch6.best_score_)
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65[LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# [LightGBM] [Warning] feature_fraction is set=0.65, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.65
# ...
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [-1.95010679e+08 -1.94031108e+08 -1.94616921e+08 -1.96078572e+08
#  -1.96457057e+08 -1.95935124e+08 -1.94569895e+08 -1.95035064e+08
#  -1.94031103e+08 -1.94615113e+08 -1.96168468e+08 -1.96457006e+08
#  -1.95935394e+08 -1.94567973e+08 -1.95033266e+08 -1.94112630e+08
#  -1.94615112e+08 -1.96168302e+08 -1.96457087e+08 -1.95936164e+08
#  -1.94569982e+08 -1.95127650e+08 -1.94034211e+08 -1.94582950e+08
#  -1.96168396e+08 -1.96457339e+08 -1.95935593e+08 -1.94458084e+08
#  -1.95191102e+08 -1.94004925e+08 -1.94697000e+08 -1.96244533e+08
#  -1.96423103e+08 -1.95869887e+08 -1.94457346e+08 -1.95152901e+08
#  -1.94593675e+08 -1.94968783e+08 -1.96182597e+08 -1.96544445e+08
#  -1.95384312e+08 -1.94844421e+08 -1.95035952e+08 -1.94381436e+08
#  -1.94830779e+08 -1.96527992e+08 -1.96392124e+08 -1.95446413e+08
#  -1.95112500e+08]
# [{'reg_alpha': 0, 'reg_lambda': 0}, {'reg_alpha': 0, 'reg_lambda': 0.001}, {'reg_alpha': 0, 'reg_lambda': 0.01}, {'reg_alpha': 0, 'reg_lambda': 0.03}, {'reg_alpha': 0, 'reg_lambda': 0.08}, {'reg_alpha': 0, 'reg_lambda': 0.3}, {'reg_alpha': 0, 'reg_lambda': 0.5}, {'reg_alpha': 0.001, 'reg_lambda': 0}, {'reg_alpha': 0.001, 'reg_lambda': 0.001}, {'reg_alpha': 0.001, 'reg_lambda': 0.01}, {'reg_alpha': 0.001, 'reg_lambda': 0.03}, {'reg_alpha': 0.001, 'reg_lambda': 0.08}, {'reg_alpha': 0.001, 'reg_lambda': 0.3}, {'reg_alpha': 0.001, 'reg_lambda': 0.5}, {'reg_alpha': 0.01, 'reg_lambda': 0}, {'reg_alpha': 0.01, 'reg_lambda': 0.001}, {'reg_alpha': 0.01, 'reg_lambda': 0.01}, {'reg_alpha': 0.01, 'reg_lambda': 0.03}, {'reg_alpha': 0.01, 'reg_lambda': 0.08}, {'reg_alpha': 0.01, 'reg_lambda': 0.3}, {'reg_alpha': 0.01, 'reg_lambda': 0.5}, {'reg_alpha': 0.03, 'reg_lambda': 0}, {'reg_alpha': 0.03, 'reg_lambda': 0.001}, {'reg_alpha': 0.03, 'reg_lambda': 0.01}, {'reg_alpha': 0.03, 'reg_lambda': 0.03}, {'
# {'reg_alpha': 0.08, 'reg_lambda': 0.001}
# -194004924.5254143

# %%
params = {
		    'boosting_type': 'gbdt', 
		    'objective': 'regression', 
		    'learning_rate': 0.01, 
		    'num_leaves': 50, 
		    'max_depth': 14,
			'min_child_samples': 21,   			#min_child_samples
			'min_child_weight': 0.001,	#min_child_weight
			'subsample': 1.0,					#bagging_fraction
			'colsample_bytree': 0.8,			#feature_fraction
			'reg_alpha': 0.01,					#reg_alpha
			'reg_lambd': 0,						#reg_lambd
    }
data_train = lgb.Dataset(x_train, y_train, silent=True)
cv_results = lgb.cv(params, data_train, 
					num_boost_round=50000, 
					nfold=5, 
					stratified=False, 
					shuffle=True, 
					metrics='rmse',    #均方误差
					early_stopping_rounds=50, 
					verbose_eval=100, 
					show_stdv=True)
print('best n_estimators:', len(cv_results['rmse-mean']))
print('best cv score:', cv_results['rmse-mean'][-1])

# %% [markdown]
# ### 3.2.1 gbm单模型批量训练

# %%
import joblib


def mutiTrain_GBM(start, end):
    for i in range(start, end+1):
        n = 2 - len(str(i))
        filename = '0' * n + str(i) + '.csv'
        data = pd.read_csv("区域赛训练集/" + filename)
        data.dropna(subset=["YD15"], inplace=True)
        data_mean = data.mean(axis=0)
        data = data.fillna(value=data_mean)
        new_data = data.copy()
        train = new_data[
            ["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
        print(train.shape)
        target = new_data[['YD15']].values
        # %%
        x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
        print(type(x_train))
        #定义模型 这里参数自行设定，获取不同调优结果，也可采用CV来调参
        gbm = LGBMRegressor(
            boosting_type = 'gbdt', 
		    objective = 'regression', 
		    learning_rate = 0.01, 
            n_estimators = 2,
            n_jobs = -1,
		    num_leaves = 50, 
		    max_depth = 14,
			min_child_samples = 21,   			#min_child_samples
			min_child_weight = 0.001,	        #min_child_weight
			subsample = 1.0,					#bagging_fraction
			colsample_bytree = 0.8,		    	#feature_fraction
			reg_alpha = 0.01,					#reg_alpha
			reg_lambd = 0,						#reg_lambd
        )
        # 模型训练
        # 指定训练集，验证集，采用l1正则化验证评估，10rounds训练损失没有下降停止，可以增至200~2000左右，这个本地训练更快一些
        gbm = gbm.fit(x_train, y_train, eval_set=[(x_test, y_test)], eval_metric="l1",callbacks=[early_stopping(stopping_rounds=1000)])
        # 模型预测
        y_pre_gbm = gbm.predict(x_test)
        # 模型评估
        print(f"gbm {i} mean_absolute_error:{mean_squared_error(y_test, y_pre_gbm)}")
        print(f"gbm {i} score:{gbm.score(x_test, y_test)}")
        joblib.dump(gbm, 'model/gbm' + str(i) + '.pkl')

# %%
# %%time
mutiTrain_GBM(11, 20)
# Out:
# (23136, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 42855	valid_0's l2: 2.78684e+09
# gbm 11 mean_absolute_error:2786836431.766496
# gbm 11 score:0.03422910209864927
# (23232, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 29573.8	valid_0's l2: 1.25154e+09
# gbm 12 mean_absolute_error:1251543443.7958374
# gbm 12 score:0.03678970577068219
# (37824, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 24129.9	valid_0's l2: 8.08221e+08
# gbm 13 mean_absolute_error:808221411.993305
# gbm 13 score:0.03669223454696735
# (37728, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 14566.9	valid_0's l2: 3.29741e+08
# gbm 14 mean_absolute_error:329741279.6546267
# gbm 14 score:0.033452231906680674
# (43680, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 32574.9	valid_0's l2: 1.51803e+09
# gbm 15 mean_absolute_error:1518031885.4795637
# gbm 15 score:0.03869916285303521
# (13759, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 20696.7	valid_0's l2: 6.29467e+08
# gbm 16 mean_absolute_error:629467103.7188874
# gbm 16 score:0.03791339877382549
# (37824, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 24546.2	valid_0's l2: 8.3972e+08
# gbm 17 mean_absolute_error:839720205.1602226
# gbm 17 score:0.037645785829309
# (12863, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 11044.6	valid_0's l2: 1.60001e+08
# gbm 18 mean_absolute_error:160000596.76046148
# gbm 18 score:0.03639124345889666
# (12181, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 35529.3	valid_0's l2: 2.14393e+09
# gbm 19 mean_absolute_error:2143926491.0147462
# gbm 19 score:0.036778912864047775
# (20390, 7)
# <class 'numpy.ndarray'>
# [LightGBM] [Warning] Unknown parameter: reg_lambd
# Training until validation scores don't improve for 1000 rounds
# Did not meet early stopping. Best iteration is:
# [2]	valid_0's l1: 12493.1	valid_0's l2: 2.18746e+08
# gbm 20 mean_absolute_error:218746054.21934146
# gbm 20 score:0.036606834279514944
# CPU times: user 13.3 s, sys: 58.7 ms, total: 13.4 s
# Wall time: 5.72 s

# %% [markdown]
# ## 4.1 方案一：预测
# ### 4.1.1 GCN单模型加载

# %%
from sklearn.metrics import mean_squared_error

for i in range(1, 11):
    n = 2 - len(str(i))
    filename = '0' * n + str(i) + '.csv'
    data = pd.read_csv("功率预测竞赛赛题与数据集/" + filename)

    # ===========异常值处理===========
    # 当实际风速为0时，功率置为0
    data.loc[data['ROUND(A.WS,1)']==0, 'YD15'] = 0

    # TODO 风速过大但功率为0的异常：先设计函数拟合出：实际功率=f(风速)，
    # 然后代入异常功率的风速获取理想功率，替换原异常功率

    # TODO 对于在特定风速下的离群功率（同时刻用IQR检测出来），做功率修正（如均值修正）
    for sp in data['WINDSPEED'].unique():
        dfs = data.loc[data['WINDSPEED']==sp,'YD15']
        dfs=dfs.sort_values()
        Q1=dfs.quantile(0.25)
        Q3=dfs.quantile(0.75)
        IQR=Q3-Q1;
        down=Q1-1.5*IQR
        up=Q3+1.5*IQR
        data.loc[(data['WINDSPEED']==sp)&(data['YD15']<down),'YD15']=down
        data.loc[(data['WINDSPEED']==sp)&(data['YD15']>up),'YD15']=up

    data.dropna(subset=["YD15"], inplace=True)
    data_mean = data.mean(axis=0)
    data = data.fillna(value=data_mean)
    new_data = data.copy()
    train = new_data[["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
    print(train.shape)
    target = new_data[['YD15']].values
    x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
    model_dict = paddle.load("model/" + str(i) + ".pdparams")
    model = GCN(input_size=7, hidden_size=64, output_size=1)
    model.set_state_dict(model_dict)
    # 开启评估模式
    model.eval()
    with paddle.no_grad():
        adj = paddle.ones((x_test.shape[0], x_test.shape[0]))  # 假设所有节点之间都有连接
        output = model(paddle.to_tensor(x_test, dtype="float32"), adj).numpy()
        # print(output)
        # print(output.shape)
        print(f"GCN_MODEL {i} mean_absolute_error:{mean_absolute_error(y_test, output)}")
# Out:
# (34398, 7)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_220/2316796771.py in <module>
#      33     target = new_data[['YD15']].values
#      34     x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
# ---> 35     model_dict = paddle.load("model/" + str(i) + ".pdparams")
#      36     model = GCN(input_size=7, hidden_size=64, output_size=1)
#      37     model.set_state_dict(model_dict)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/framework/io.py in load(path, **configs)
#    1101
#    1102     else:
# -> 1103         load_result = _legacy_load(path, **configs)
#    1104
#    1105     return load_result
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/framework/io.py in _legacy_load(path, **configs)
#    1122     else:
#    1123         # file prefix and directory are compatible cases
# -> 1124         model_path, config = _build_load_path_and_config(path, config)
#    1125         # check whether model file exists
#    1126         if config.model_filename is None:
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/framework/io.py in _build_load_path_and_config(path, config)
#     198                 "`paddle.load('model')`."
#     199             )
# --> 200         raise ValueError(error_msg % path)
#     201     else:
#     202         if prefix_format_exist:
#
# ValueError: The ``path`` (model/1.pdparams) to load model not exists.

# %% [markdown]
# ## 4.1 方案一：预测
# ### 4.1.2 GBM单模型加载

# %%
for i in range(1, 11):
    n = 2 - len(str(i))
    filename = '0' * n + str(i) + '.csv'
    data = pd.read_csv("功率预测竞赛赛题与数据集/" + filename)
    data.dropna(subset=["YD15"], inplace=True)
    data_mean = data.mean(axis=0)
    data = data.fillna(value=data_mean)
    new_data = data.copy()
    train = new_data[["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
    print(train.shape)
    target = new_data[['YD15']].values
    x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
    gbm = joblib.load('model/gbm' + str(i) + '.pkl')
    y_pre_gbm = gbm.predict(x_test)
    print(f"gbm {i} mean_absolute_error:{mean_absolute_error(y_test, y_pre_gbm)}")
    print(f"gbm {i} score:{gbm.score(x_test, y_test)}")

# %% [markdown]
# ## 4.2 模型组合
# ### 4.2.1 GCN+GBM模型加载

# %%
def load_models(turb_id):
    model_dict = paddle.load("model/" + str(turb_id) + ".pdparams")
    model1 = GCN(input_size=7, hidden_size=64, output_size=1)
    model2 = joblib.load("model/gbm" + str(turb_id) + '.pkl')
    model1.set_state_dict(model_dict)
    # 开启评估模式
    model1.eval()
    return [model1, model2]

# %%
for i in range(1, 11):
    n = 2 - len(str(i))
    filename = '0' * n + str(i) + '.csv'
    data = pd.read_csv("功率预测竞赛赛题与数据集/" + filename)
    data.dropna(subset=["YD15"], inplace=True)
    data_mean = data.mean(axis=0)
    data = data.fillna(value=data_mean)
    new_data = data.copy()
    train = new_data[["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
    print(train.shape)
    target = new_data[['YD15']]
    x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
    models=load_models(i)
    with paddle.no_grad():
        adj = paddle.ones((x_test.shape[0], x_test.shape[0]))  # 假设所有节点之间都有连接
        output1 = models[0](paddle.to_tensor(x_test, dtype="float32"), adj).numpy().flatten()
        output2 = models[1].predict(x_test)
        # 惩罚权重自行设定，建议outputs1小，output2大
        output = (-0.01 * output1 + 0.99 * output2)
        print(f"composition model {i} mean_absolute_error:{mean_absolute_error(y_test, output)}")

# %% [markdown]
# ## 5 Tip
# ### 模型参数请自行组合，注释部分有建议值
# ### 提交脚本可参照上述4.2编写，也可以参考笔者的predict.py文件，为了测试笔者在基线作者infile目录下拷贝了一下0002in.csv重命名为0001in.csv

# %%
data = pd.read_csv("区域赛训练集/" + turb_id)
# data = pd.read_csv("区域赛训练集/" + filename)
data.dropna(subset=["YD15"], inplace=True)
data_mean = data.mean(axis=0)
data = data.fillna(value=data_mean)
new_data = data.copy()
train = new_data[
    ["WINDSPEED", "PREPOWER", "WINDDIRECTION", "TEMPERATURE", "HUMIDITY", "PRESSURE", "ROUND(A.WS,1)"]]
print(train.shape)
target = new_data[['YD15']].values
# %%
x_train, x_test, y_train, y_test = train_test_split(train.values, target, test_size=0.1)
print(type(x_train))
#定义模型 这里参数自行设定，获取不同调优结果，也可采用CV来调参
gbm = LGBMRegressor(
    boosting_type = 'gbdt', 
	objective = 'regression', 
	learning_rate = 0.01, 
    n_estimators = 2,
    n_jobs = -1,
    num_leaves = 50, 
    max_depth = 14,
	min_child_samples = 21,   			#min_child_samples
	min_child_weight = 0.001,	        #min_child_weight
	subsample = 1.0,					#bagging_fraction
	colsample_bytree = 0.8,		    	#feature_fraction
	reg_alpha = 0.01,					#reg_alpha
	reg_lambd = 0,						#reg_lambd
)
# 模型训练
# 指定训练集，验证集，采用l1正则化验证评估，10rounds训练损失没有下降停止，可以增至200~2000左右，这个本地训练更快一些
gbm = gbm.fit(x_train, y_train, eval_set=[(x_test, y_test)], eval_metric="l1",callbacks=[early_stopping(stopping_rounds=1000)])
# 模型预测
y_pre_gbm = gbm.predict(x_test)
# 模型评估
print(f"gbm {i} mean_absolute_error:{mean_squared_error(y_test, y_pre_gbm)}")
print(f"gbm {i} score:{gbm.score(x_test, y_test)}")
joblib.dump(gbm, 'model/gbm' + str(i) + '.pkl')
